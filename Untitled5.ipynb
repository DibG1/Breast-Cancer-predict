# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/Breast_cancer_data.csv",na_values=[np.nan,'na',"NA",'n/a',"N/A","--","-"])

# %%
data
# Out:
#      mean_radius  mean_texture  ...  mean_smoothness  diagnosis
# 0          17.99         10.38  ...          0.11840          0
# 1          20.57         17.77  ...          0.08474          0
# 2          19.69         21.25  ...          0.10960          0
# 3          11.42         20.38  ...          0.14250          0
# 4          20.29         14.34  ...          0.10030          0
# ..           ...           ...  ...              ...        ...
# 564        21.56         22.39  ...          0.11100          0
# 565        20.13         28.25  ...          0.09780          0
# 566        16.60         28.08  ...          0.08455          0
# 567        20.60         29.33  ...          0.11780          0
# 568         7.76         24.54  ...          0.05263          1
#
# [569 rows x 6 columns]

# %%
X=data.iloc[:,:-1]

# %%
X
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# [569 rows x 5 columns]

# %%
y=data.iloc[:,-1]
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: diagnosis, Length: 569, dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mean_radius      569 non-null    float64
#  1   mean_texture     569 non-null    float64
#  2   mean_perimeter   569 non-null    float64
#  3   mean_area        569 non-null    float64
#  4   mean_smoothness  569 non-null    float64
# dtypes: float64(5)
# memory usage: 22.4 KB

# %%
X.isna().sum()
# Out:
# mean_radius        0
# mean_texture       0
# mean_perimeter     0
# mean_area          0
# mean_smoothness    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.225,random_state=1,stratify=y)

# %%
from sklearn.preprocessing import StandardScaler
sc_X=StandardScaler(with_mean=False)
X_train=sc_X.fit_transform(X_train)
X_test=sc_X.transform(X_test)

# %%
#Fitting MLPClassifier
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(random_state=1, max_iter=300).fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.92        48
#            1       0.94      0.98      0.96        81
#
#     accuracy                           0.95       129
#    macro avg       0.95      0.94      0.94       129
# weighted avg       0.95      0.95      0.95       129

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[43,  5],
#        [ 2, 79]])

# %%
# pickling the model
import pickle
pickle_out = open("clf_cancer.pkl", "wb")
pickle.dump(clf, pickle_out)

pickle_out.close()

# %%
X.columns
# Out:
# Index(['mean_radius', 'mean_texture', 'mean_perimeter', 'mean_area',
#        'mean_smoothness'],
#       dtype='object')

# %%
# Out:
#        Updated On                        State  ...  Source3 Source 4
# 0      17/04/2020  Andaman and Nicobar Islands  ...      NaN      NaN
# 1      24/04/2020  Andaman and Nicobar Islands  ...      NaN      NaN
# 2      27/04/2020  Andaman and Nicobar Islands  ...      NaN      NaN
# 3      01/05/2020  Andaman and Nicobar Islands  ...      NaN      NaN
# 4      16/05/2020  Andaman and Nicobar Islands  ...      NaN      NaN
# ...           ...                          ...  ...      ...      ...
# 12181  07/04/2021                  West Bengal  ...      NaN      NaN
# 12182  08/04/2021                  West Bengal  ...      NaN      NaN
# 12183  09/04/2021                  West Bengal  ...      NaN      NaN
# 12184  10/04/2021                  West Bengal  ...      NaN      NaN
# 12185  11/04/2021                  West Bengal  ...      NaN      NaN
#
# [12186 rows x 55 columns]

# %%
# Out:
#       Updated On  ...                                           Source 4
# 0     17/04/2020  ...                                                NaN
# 1     24/04/2020  ...                                                NaN
# 2     27/04/2020  ...                                                NaN
# 3     01/05/2020  ...                                                NaN
# 4     16/05/2020  ...                                                NaN
# ...          ...  ...                                                ...
# 5184  13/02/2021  ...  https://covid19dashboard.jharkhand.gov.in/Bull...
# 5185  14/02/2021  ...  https://covid19dashboard.jharkhand.gov.in/Bull...
# 5186  15/02/2021  ...  https://covid19dashboard.jharkhand.gov.in/Bull...
# 5187  16/02/2021  ...  https://covid19dashboard.jharkhand.gov.in/Bull...
# 5188  17/02/2021  ...                                                NaN
#
# [5189 rows x 55 columns]
